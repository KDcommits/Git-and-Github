# %% [markdown]
# <h1 align="center"> Git & Github </h1>

# %% [markdown]
# **Git** is a distributed version control software.<br>
# **Git bach** is a git terminal which works like unix.The commands are similar that of unix/linux <br>

# %% [markdown]
# ## STEP 1 : Installation

# %% [markdown]
# - Download Link : https://git-scm.com/download/win<br>
# - Download for 64 bit windows version <br>
# ![image.png](attachment:image.png)
# -  Install with default options with no change.
# - Navigate to the desired folder where gitbash is supposed to be open. Right click -> Git Bash here.
# - Open the git bash. The interface looks something like this,
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## STEP 2 : Configuration

# %% [markdown]
# - It's important to set up the proper configuration with email and password. So the changes by the git commits can be backtracked.
# - Commands to set username and email id are as follows :
#     - ***git config --global user.name Krishnendu***
#     - ***git config --global user.email kd.datascience@gmail.com***
# - To check if the email and username has been set properly or not write the command :
#     - ***git config --global user.email***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## STEP 3 : Untracked and Staged files

# %% [markdown]
# ![image.png](attachment:image.png)
# - Staging helps to choose what files you would like to push for commit. Say there are 4 files we have worked on but we want to push only 2 files so before commit we would stage the files so that we can commit and push only those 2. Commiting directly will lead to make changes in all 4 files.

# %% [markdown]
# - Initialize the git repository first if you are creating a repo from the scratch.Command :
#    - ***git init***
# - After initializing the repository a file with .git extension will be created which will contain the binaries.
# - Create a dummy file main.py in the same folder
# - To know the status of the files that are pushed via commit
#     - ***git status***
# -  The below ss shows the files that we have currently are untracked.
# ![image.png](attachment:image.png)
# - Now we need to bring those files into the staging area that we would like to push for commit. Command to bring files into staging area:
#     - ***git add \<filename\>***
#     - ***git add -A***     <i>---- Adds all the files within the directory to the staging area </i>
# - Now when we again check for status then it says "no commits yet". So we need to make a commit for the staged files.
# ![image-2.png](attachment:image-2.png)
#
# - Now run the command ***git commit***. It will commit the changes only for the staged files and open vm editor. Press "i" key on the keyboard to write a text. This is basically the message for that commit so that other developers can understand what the commit is for. <br>
# ![image-3.png](attachment:image-3.png)
#
# -  When you are done with writing the commit message, then click on "**esc**" key and then write **:wq** to save the commit. It will exit the vm editor and the commit will be shown.![image-7.png](attachment:image-7.png)
# - The below screenshot shows the status of the file "Git and Github.ipynb" is untracked. This is because we had only staged for "main.py" file. This proves the commit that we did only made changes to the "main.py" file.
# ![image-5.png](attachment:image-5.png)
# - There is a simpler way of pushing commits without even opening vm editor.Command:
#     - ***git commit -m "\<type the message\>"***
#
#  ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ## STEP 4: Git Ignore

# %% [markdown]
# - It helps to ignore pushing those files which are temporarily created and do not require to be pushed to the remote repo. Typically log files , image files, binary files are avoided to be pushed.
# - Use the following commands to create a .gitignore file to avoid pushing unneccasry files. Add the filename (mylogs.txt) in the .gitignore file so that it will not add that filename in the commits even if they are inside a seperate directory. <br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ## STEP N : Integrating git with github.

# %% [markdown]
# - Create a github account and make a repository where you would like to push your local files to. here we created a repo Git-and-Github, and its a private repo.
# - Go to repository -> Code -> HTTPS -> Copy<br>
# Here our https link for the remote repository is : https://github.com/KDcommits/Git-and-Github.git
#
# - Using the following commands create a remote connection with local repo with the github repo.
#
# ![image.png](attachment:image.png)
#
# - Now if we want to push the files that exists in the master branch of our local "master" repo to the remote "origin repo", we need to run the following command. A pop up window will open up which will ask for credentials of the github account where the origin repo is hosted.
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### NOTES:

# %% [markdown]
# - Command to get a concise view of the file status : ***git status -s***
# - Command to get the last committed version of a file : ***git checkout \<filename\>***
# - Command to commit without staging: ***git commit -a -m "\<commit message\>"***
# - Commad to remove a staged file and convert to untacked : ***git rm --cached \<filename\>***
# - Command to get the last committed version of all files : ***git checkout -f***
# - Command to check all the commit history : ***git log***
# - Command to check only the last n commit hostory : ***git log -p -\<n\>***
